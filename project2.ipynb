# %% [markdown]
# border_2 data analysis

# %%
import pandas as pd

# %%
data =  pd.read_excel('Border2.xlsx')
data

# %%
data.head()

# %%
data.tail(10)

# %%
data.shape

# %%
"row in this data",data.shape[0]

# %%
"column in this data set ",data.shape[1]

# %%
"checking nulls ",data.isnull()

# %%
"information about this data ",data.info()

# %%
"check nulls", data.isnull().sum()

# %%
"to get statistics about this ", data.describe(include='all')

# %% [markdown]
# it means a man got top views on youtube by edit and using interview video

# %% [markdown]
# it mens the movie marketing got 3.000000e+02 + views

# %%
data['Hashtag'].mode()

# %% [markdown]
# it mean's you can use #mittikebete in instagram for more views

# %%
"here we have to find top occuring channel name " , data.Channel_Name.value_counts()

# %% [markdown]
# "data said CinemaTalks channel posted highest videos"

# %% [markdown]
# data.columns()

# %%
data.Hashtag.unique()

# %%
data.Hashtag.value_counts()

# %% [markdown]
# valuecount use to find condition on specific thing

# %%
data['Channel_Name'].value_counts()

# %%
data.columns

# %%
data.Official_or_Fan.value_counts()

# %%
(data[data['Channel_Name'].str.contains('CinemaTalks')])

# %%
data['Channel_Name'].describe()

# %%
data['Likes'].describe()

# %%
data['Views'].describe()

# %% [markdown]
# perform specific task on perticular condition

# %% [markdown]
# data about #mittikebete

# %%
data[data['Channel_Name']=='CinemaTalks']

# %%
data[data['Channel_Name']=='CinemaTalks']['Likes']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(data['Hashtag'],data['Views'])

# %%
#top 5 channel
data['Hashtag'].value_counts()
